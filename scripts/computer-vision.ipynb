# %%
from ultralytics import YOLO
import cv2
import math

# %%
# model
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
# Out:
# True

# %%
while True:
    success, img = cap.read()
    img = cv2.flip(img, 1)
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 6 persons, 1 laptop, 107.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 3.0ms preprocess, 107.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 2 laptops, 82.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.6ms preprocess, 82.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 laptops, 71.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 2.0ms preprocess, 71.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 laptops, 67.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> laptop
# Speed: 2.3ms preprocess, 67.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 laptops, 93.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> laptop
# Speed: 2.4ms preprocess, 93.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 82.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> laptop
# Speed: 2.3ms preprocess, 82.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 2 laptops, 73.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 2.2ms preprocess, 73.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 2 laptops, 62.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.8ms preprocess, 62.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 2 laptops, 76.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.9ms preprocess, 76.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 1 laptop, 72.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 2.0ms preprocess, 72.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 2 laptops, 69.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 1.8ms preprocess, 69.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 1 laptop, 68.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 2.2ms preprocess, 68.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 65.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.4ms preprocess, 65.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 64.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Speed: 1.8ms preprocess, 64.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 laptop, 68.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.38
# Class name --> bottle
# Speed: 1.9ms preprocess, 68.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 69.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.36
# Class name --> bottle
# Speed: 1.8ms preprocess, 69.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.0ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.0ms preprocess, 65.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 65.7ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.2ms preprocess, 65.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 cup, 68.1ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.0ms preprocess, 68.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 bottle, 1 cup, 66.4ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.9ms preprocess, 66.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 1 cup, 68.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.64
# Class name --> bottle
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Speed: 2.0ms preprocess, 68.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 bottles, 1 cup, 1 laptop, 69.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> bottle
# Speed: 1.8ms preprocess, 69.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 cup, 63.3ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.2ms preprocess, 63.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 bottles, 1 cup, 2 laptops, 66.5ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.6
# Class name --> cup
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.8ms preprocess, 66.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 bottles, 1 cup, 2 laptops, 66.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.1ms preprocess, 66.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 1 cup, 1 laptop, 68.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.57
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.5
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.9ms preprocess, 68.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 bananas, 72.0ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.41
# Class name --> banana
# Confidence ---> 0.28
# Class name --> banana
# Speed: 2.0ms preprocess, 72.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 1 banana, 68.8ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.62
# Class name --> bottle
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.33
# Class name --> banana
# Speed: 2.2ms preprocess, 68.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 bottles, 1 cup, 73.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.72
# Class name --> bottle
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> cup
# Speed: 2.1ms preprocess, 73.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 sandwich, 74.2ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.6
# Class name --> cup
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> sandwich
# Speed: 1.9ms preprocess, 74.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 bottles, 1 banana, 1 laptop, 64.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.64
# Class name --> bottle
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> banana
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 1.8ms preprocess, 64.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 73.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.52
# Class name --> bottle
# Speed: 2.0ms preprocess, 73.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 1 cup, 1 dining table, 1 laptop, 69.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> cup
# Confidence ---> 0.29
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 2.1ms preprocess, 69.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 71.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.9ms preprocess, 71.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 cup, 1 sandwich, 2 laptops, 69.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.32
# Class name --> sandwich
# Speed: 2.1ms preprocess, 69.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 cup, 1 sandwich, 2 laptops, 69.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.32
# Class name --> sandwich
# Speed: 2.0ms preprocess, 69.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dog, 2 bottles, 1 cup, 1 laptop, 72.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.65
# Class name --> bottle
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> dog
# Confidence ---> 0.33
# Class name --> cup
# Speed: 1.8ms preprocess, 72.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dog, 2 bottles, 1 cup, 1 laptop, 68.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.48
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> dog
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.37
# Class name --> bottle
# Speed: 2.0ms preprocess, 68.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 cup, 1 pizza, 1 dining table, 2 laptops, 62.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> pizza
# Confidence ---> 0.29
# Class name --> diningtable
# Speed: 1.8ms preprocess, 62.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dog, 2 bottles, 1 cup, 2 laptops, 67.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.5
# Class name --> cup
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> dog
# Speed: 2.1ms preprocess, 67.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dog, 2 bottles, 1 cup, 2 laptops, 71.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> dog
# Speed: 1.2ms preprocess, 71.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 cup, 2 laptops, 68.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 1.8ms preprocess, 68.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 1 cup, 2 laptops, 73.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> bottle
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.32
# Class name --> bottle
# Speed: 16.6ms preprocess, 73.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 cup, 2 laptops, 133.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.53
# Class name --> bottle
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 1.8ms preprocess, 133.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 1 cup, 1 dining table, 61.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.6
# Class name --> bottle
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 1.9ms preprocess, 61.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 1 cup, 68.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.42
# Class name --> cup
# Confidence ---> 0.3
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.9ms preprocess, 68.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 1 wine glass, 1 cup, 1 banana, 65.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> banana
# Confidence ---> 0.28
# Class name --> wine glass
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.9ms preprocess, 65.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 65.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.39
# Class name --> cup
# Speed: 1.8ms preprocess, 65.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 65.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.37
# Class name --> bottle
# Speed: 1.2ms preprocess, 65.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 67.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.28
# Class name --> cup
# Speed: 2.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 73.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.28
# Class name --> cup
# Speed: 1.2ms preprocess, 73.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 69.1ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 2.3ms preprocess, 69.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 75.2ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.9ms preprocess, 75.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 71.7ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.9ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.9ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 69.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 2.2ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.9ms preprocess, 84.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.2ms preprocess, 66.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.9ms preprocess, 70.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 pizza, 64.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.41
# Class name --> wine glass
# Confidence ---> 0.26
# Class name --> pizza
# Speed: 2.0ms preprocess, 64.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 65.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 60.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.1ms preprocess, 60.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 wine glass, 1 pizza, 69.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> pizza
# Confidence ---> 0.26
# Class name --> wine glass
# Speed: 1.4ms preprocess, 69.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 67.3ms
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.0ms preprocess, 67.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.5ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.2ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 68.3ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Speed: 1.8ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 cup, 64.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 1.7ms preprocess, 64.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cup, 71.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.72
# Class name --> cup
# Confidence ---> 0.26
# Class name --> cat
# Speed: 2.1ms preprocess, 71.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 66.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 2.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.3ms preprocess, 68.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.5ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 1.9ms preprocess, 69.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 69.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Speed: 2.3ms preprocess, 69.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.2ms preprocess, 73.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 cup, 1 broccoli, 65.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> broccoli
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 65.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 cup, 67.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 1.9ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 cup, 65.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.63
# Class name --> cup
# Confidence ---> 0.54
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 65.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 cup, 66.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.41
# Class name --> bottle
# Speed: 2.3ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.2ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 67.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.8ms preprocess, 67.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.7ms preprocess, 65.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 66.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 2.2ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 66.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 2.1ms preprocess, 66.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 70.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 2.0ms preprocess, 70.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 67.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.1ms preprocess, 67.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.4ms preprocess, 63.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 70.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 2.0ms preprocess, 70.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 63.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.2ms preprocess, 63.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 62.2ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.1ms preprocess, 62.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 64.3ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.2ms preprocess, 64.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.6ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.2ms preprocess, 68.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bowl, 1 cell phone, 65.8ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.4
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.3
# Class name --> bowl
# Speed: 2.0ms preprocess, 65.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 cup, 67.8ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.33
# Class name --> bottle
# Speed: 1.9ms preprocess, 67.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.9ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.8ms preprocess, 69.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 68.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.0ms preprocess, 68.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.1ms preprocess, 66.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.9ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.1ms preprocess, 64.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 68.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 2.0ms preprocess, 68.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 pizza, 63.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.27
# Class name --> pizza
# Confidence ---> 0.26
# Class name --> cup
# Speed: 1.3ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 wine glass, 1 cup, 57.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> wine glass
# Speed: 1.9ms preprocess, 57.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 wine glass, 1 cup, 67.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.45
# Class name --> bottle
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> wine glass
# Speed: 2.0ms preprocess, 67.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 bottles, 1 cup, 68.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.67
# Class name --> cup
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 2.1ms preprocess, 68.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 bottles, 1 cup, 74.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 2.0ms preprocess, 74.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 wine glass, 1 cup, 62.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.76
# Class name --> cup
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.37
# Class name --> wine glass
# Speed: 2.1ms preprocess, 62.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 65.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.1ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 wine glass, 1 cup, 66.0ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.32
# Class name --> wine glass
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.2ms preprocess, 66.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dog, 1 bottle, 1 wine glass, 1 cup, 63.3ms
# Confidence ---> 0.82
# Class name --> cup
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.52
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> wine glass
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> dog
# Speed: 1.9ms preprocess, 63.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 bottles, 1 cup, 65.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.77
# Class name --> cup
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 2.0ms preprocess, 65.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 bottles, 1 cup, 66.9ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.75
# Class name --> cup
# Confidence ---> 0.58
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 1.9ms preprocess, 66.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 69.5ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.9ms preprocess, 69.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cups, 1 banana, 59.5ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.69
# Class name --> cup
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.39
# Class name --> banana
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.9ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 wine glass, 1 cup, 65.8ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.75
# Class name --> cup
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.27
# Class name --> wine glass
# Speed: 1.3ms preprocess, 65.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 1 wine glass, 2 cups, 62.1ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.77
# Class name --> cup
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.37
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> wine glass
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> bottle
# Speed: 1.6ms preprocess, 62.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 bottles, 2 cups, 1 chair, 64.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> cup
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> cup
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> chair
# Speed: 2.0ms preprocess, 64.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 bottles, 2 cups, 1 chair, 65.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> cup
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> bottle
# Confidence ---> 0.31
# Class name --> cup
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> chair
# Speed: 2.3ms preprocess, 65.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 70.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.52
# Class name --> wine glass
# Confidence ---> 0.34
# Class name --> bottle
# Speed: 1.4ms preprocess, 70.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 2 wine glasss, 1 cup, 60.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.42
# Class name --> wine glass
# Confidence ---> 0.42
# Class name --> cup
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> wine glass
# Speed: 2.0ms preprocess, 60.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 bottles, 1 cup, 63.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.8ms preprocess, 63.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 bottles, 1 wine glass, 1 cup, 64.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.57
# Class name --> cup
# Confidence ---> 0.51
# Class name --> wine glass
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.4ms preprocess, 64.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 68.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.4ms preprocess, 68.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 bottles, 1 cup, 60.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.33
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> cup
# Speed: 1.9ms preprocess, 60.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 bottles, 1 wine glass, 67.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.36
# Class name --> wine glass
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 67.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 70.6ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.9ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 wine glass, 2 cups, 61.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.49
# Class name --> bottle
# Confidence ---> 0.42
# Class name --> cup
# Confidence ---> 0.39
# Class name --> wine glass
# Confidence ---> 0.3
# Class name --> cup
# Speed: 2.0ms preprocess, 61.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 bottles, 2 cups, 69.4ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.78
# Class name --> cup
# Confidence ---> 0.62
# Class name --> cup
# Confidence ---> 0.41
# Class name --> bottle
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.8ms preprocess, 69.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 cups, 61.9ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.76
# Class name --> cup
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.39
# Class name --> cup
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.37
# Class name --> bottle
# Speed: 1.2ms preprocess, 61.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 wine glass, 2 cups, 1 remote, 2 cell phones, 62.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> cup
# Confidence ---> 0.59
# Class name --> cell phone
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.38
# Class name --> cup
# Confidence ---> 0.36
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> wine glass
# Confidence ---> 0.27
# Class name --> remote
# Speed: 2.1ms preprocess, 62.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cups, 1 cell phone, 63.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.77
# Class name --> cup
# Confidence ---> 0.52
# Class name --> cup
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.8ms preprocess, 63.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 4 cups, 64.4ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.57
# Class name --> cup
# Confidence ---> 0.51
# Class name --> cup
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.32
# Class name --> cup
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> cup
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.2ms preprocess, 64.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cups, 69.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.8ms preprocess, 69.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 cups, 63.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.2ms preprocess, 63.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 65.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.9ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cups, 63.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Speed: 1.4ms preprocess, 63.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 cell phone, 67.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.7ms preprocess, 67.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 cups, 64.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.33
# Class name --> cup
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.2ms preprocess, 64.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tie, 2 cups, 64.8ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.33
# Class name --> tie
# Speed: 1.3ms preprocess, 64.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 63.3ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> cup
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.2ms preprocess, 63.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 62.7ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# ...
# Confidence ---> 0.47
# Class name --> bottle
# Speed: 2.0ms preprocess, 59.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 68.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> cup
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.1ms preprocess, 68.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 68.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 68.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 cup, 1 laptop, 64.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.8ms preprocess, 64.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 cup, 1 laptop, 66.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.43
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.9ms preprocess, 66.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 bottles, 1 cup, 1 laptop, 70.8ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.59
# Class name --> cup
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Speed: 1.8ms preprocess, 70.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 bottles, 1 cup, 1 laptop, 64.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.59
# Class name --> cup
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> bottle
# Speed: 2.1ms preprocess, 64.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 2 cups, 1 laptop, 71.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.59
# Class name --> cup
# Confidence ---> 0.36
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> cup
# Speed: 2.1ms preprocess, 71.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 cup, 1 laptop, 62.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Confidence ---> 0.47
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 62.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 1 cup, 1 laptop, 63.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.59
# Class name --> cup
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.51
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.8ms preprocess, 63.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 wine glass, 1 cup, 1 laptop, 66.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Confidence ---> 0.3
# Class name --> wine glass
# Speed: 1.9ms preprocess, 66.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 wine glass, 1 cup, 1 laptop, 65.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.34
# Class name --> wine glass
# Speed: 1.3ms preprocess, 65.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 66.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.4ms preprocess, 66.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 cup, 1 banana, 1 laptop, 70.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.39
# Class name --> banana
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.9ms preprocess, 70.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 cup, 1 banana, 1 laptop, 68.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> cup
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> banana
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.6ms preprocess, 68.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 cup, 1 laptop, 1 cell phone, 67.3ms
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.54
# Class name --> cell phone
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.9ms preprocess, 67.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 wine glass, 1 cup, 1 chair, 1 laptop, 68.0ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> cup
# Confidence ---> 0.4
# Class name --> wine glass
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 68.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 bottle, 1 cup, 66.5ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.57
# Class name --> cup
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 1.2ms preprocess, 66.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 65.6ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.9ms preprocess, 65.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 67.3ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.42
# Class name --> cup
# Speed: 2.1ms preprocess, 67.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cups, 68.1ms
# Confidence ---> 0.82
# Class name --> cup
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 1.8ms preprocess, 68.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cups, 66.6ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.73
# Class name --> cup
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.57
# Class name --> cup
# Speed: 2.1ms preprocess, 66.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 bottles, 1 cup, 65.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.9ms preprocess, 65.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 bottles, 1 cup, 60.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.31
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.0ms preprocess, 60.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 bowl, 69.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.26
# Class name --> bowl
# Speed: 2.1ms preprocess, 69.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 cup, 1 bowl, 65.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.46
# Class name --> bowl
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.9ms preprocess, 65.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cups, 1 bowl, 66.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.3
# Class name --> bowl
# Confidence ---> 0.27
# Class name --> cup
# Speed: 1.1ms preprocess, 66.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 cup, 1 bowl, 68.1ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.53
# Class name --> bowl
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 2.0ms preprocess, 68.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 64.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.46
# Class name --> wine glass
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.27
# Class name --> bottle
# Speed: 1.4ms preprocess, 64.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 bowl, 65.0ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.34
# Class name --> bowl
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.8ms preprocess, 65.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 wine glass, 1 cup, 1 bowl, 63.6ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.43
# Class name --> bowl
# Confidence ---> 0.38
# Class name --> wine glass
# Confidence ---> 0.38
# Class name --> cup
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.8ms preprocess, 63.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 wine glass, 1 cup, 71.8ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> wine glass
# Confidence ---> 0.38
# Class name --> cup
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.2ms preprocess, 71.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 cups, 69.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.39
# Class name --> cup
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.35
# Class name --> cup
# Speed: 1.8ms preprocess, 69.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 2 bowls, 64.5ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.43
# Class name --> bowl
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.32
# Class name --> bowl
# Speed: 1.3ms preprocess, 64.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 wine glass, 2 cups, 67.8ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.44
# Class name --> wine glass
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Speed: 2.0ms preprocess, 67.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 2 bowls, 59.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.39
# Class name --> cup
# Confidence ---> 0.33
# Class name --> bowl
# Confidence ---> 0.27
# Class name --> bowl
# Speed: 2.2ms preprocess, 59.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 2 bowls, 1 toothbrush, 65.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.41
# Class name --> bowl
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.35
# Class name --> toothbrush
# Confidence ---> 0.34
# Class name --> bowl
# Confidence ---> 0.32
# Class name --> cup
# Speed: 1.1ms preprocess, 65.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 wine glass, 2 cups, 1 bowl, 59.1ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.36
# Class name --> wine glass
# Confidence ---> 0.28
# Class name --> bottle
# Confidence ---> 0.28
# Class name --> cup
# Confidence ---> 0.27
# Class name --> bowl
# Speed: 1.2ms preprocess, 59.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 cups, 2 bowls, 66.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.34
# Class name --> bowl
# Confidence ---> 0.32
# Class name --> cup
# Confidence ---> 0.31
# Class name --> bowl
# Speed: 1.8ms preprocess, 66.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
